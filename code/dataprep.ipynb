# %%
import numpy as np
import os
import StringIO
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
where = np.loadtxt(open('sample.txt'))

# %%
np.shape(what_z)
# Out:
# (200, 200)

# %%
what_z = where[0][:200**2]
what_r = where[0][-200**2:]

# %%
what_g = np.reshape(what_r,(200,200))[100:][100:]
what_r = np.reshape(what_g,(200,200))[100:][100:]

# %%
noise_g = np.random.rand(200,200)[100:][100:]
noise_r = 2.*np.random.rand(200,200)[100:][100:]

# %%
plt.imshow(np.log(what_g+np.exp(0.1))+noise_g,cmap = 'afmhot')
# Out:
# /Users/aimalz/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: RuntimeWarning: invalid value encountered in log
#   if __name__ == '__main__':

# %%
plt.imshow(np.log(what_r+np.exp(1.))+noise_r,cmap = 'afmhot')

# %%
image_g = np.log(what_g+np.exp(1.))+noise_g
image_r = np.log(what_r+np.exp(1.))+noise_r

# %%
truth_g = np.log(what_g+np.exp(1.))
truth_r = np.log(what_r+np.exp(1.))

# %%
test_image = np.array([np.ndarray.flatten(image_g),np.ndarray.flatten(image_r)])
test_truth = np.array([np.ndarray.flatten(truth_g),np.ndarray.flatten(truth_r)])
test_sigma = np.array([np.ndarray.flatten(noise_g),np.ndarray.flatten(noise_r)])

# %%
where_truth = os.path.join('Data','test_truth.txt')
where_image = os.path.join('Data','test_image.txt')
where_sigma = os.path.join('Data','test_sigma.txt')

# %%
np.savetxt(where_truth,test_truth)
np.savetxt(where_image,test_image) 
np.savetxt(where_sigma,test_sigma)
